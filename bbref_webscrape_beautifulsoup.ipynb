# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.basketball-reference.com/players/l/landrca01.html"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-root="/home/bbr/build" data-version="klecko-" itemscope="" itemtype="https://schema.org/WebSite" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
# <link href="https://d2p3bygnnzw9w3.cloudfront.net/req/201906262" rel="dns-prefetch"/>
# <!-- no:cookie fast load the css.           -->
# <link crossorigin="" href="https://d2p3bygnnzw9w3.cloudfront.net" rel="preconnect"/>
# <link crossorigin="" href="https://d2cwpp38twqe55.cloudfront.net" rel="preconnect"/>
# ...

# %%
soup.findAll('tr', limit=2)
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers
# Out:
# ['Age',
#  'Tm',
#  'Lg',
#  'Pos',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']

# %%
rows = soup.findAll('tr')[1:]
player_stats = [[td.getText() for td in rows[i].findAll('td')]
            for i in range(len(rows))]

# %%
stats = pd.DataFrame(player_stats, columns = headers)
stats.head(10)
# Out:
#   Age   Tm   Lg Pos   G  GS    MP   FG   FGA   FG%  ...    FT%  ORB  DRB  TRB  \
# 0  24  HOU  NBA  PF  42   0  16.9  3.2   5.2  .616  ...   .661  2.3  2.6  4.9
# 1  25  HOU  NBA  PF  69   0  21.3  3.5   6.1  .574  ...   .813  1.8  3.2  5.0
# 2  26  TOT  NBA  PF  80  29  30.9  6.2  11.6  .536  ...   .806  2.4  3.5  5.9
# 3  26  HOU  NBA  PF  52   1  27.2  5.8  10.6  .547  ...   .839  2.3  3.2  5.5
# 4  26  SAC  NBA  PF  28  28  37.6  7.0  13.5  .520  ...   .741  2.4  4.1  6.5
# 5  27  TOT  NBA  PF  76  26  26.4  4.5   9.0  .502  ...   .740  2.2  2.4  4.6
# 6  27  SAC  NBA  PF  53  16  26.5  4.5   9.1  .492  ...   .721  2.4  2.4  4.8
# 7  27  NOH  NBA  PF  23  10  26.2  4.7   8.8  .527  ...   .795  1.7  2.4  4.1
# 8  28  NOH  NBA  PF  41   8  24.4  4.4   8.8  .503  ...   .799  1.9  3.3  5.2
# 9  29  GSW  NBA  PF  81   2  23.2  4.0   7.4  .540  ...   .817  2.2  3.7  6.0
#
#    AST  STL  BLK  TOV   PF   PTS
# 0  0.5  0.4  0.2  0.6  2.3   8.1
# 1  0.6  0.4  0.4  1.0  2.4   9.2
# ...

# %%
url = "https://www.basketball-reference.com/players/l/landrca01.html"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)
tables = soup.find_all('table')

# %%
per_game = tables[0]
advanced = tables[1]
for tr in per_gam.find_all('tr'):
    tds = tr.find_all('td')
    tds = [td.text for ts in tds]
tds
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-30d15c89fc87> in <module>
#       1 per_game = tables[0]
# ----> 2 advanced = tables[1]
#       3 for tr in per_gam.find_all('tr'):
#       4     tds = tr.find_all('td')
#       5     tds = [td.text for ts in tds]
#
# IndexError: list index out of range

# %%
url = "https://www.basketball-reference.com/players/l/landrca01.html#all_advanced"
# this is the HTML from the given URL
html = urlopen(url)
soup = BeautifulSoup(html)
soup.findAll('tr', limit=2)
# use getText()to extract the text we need into a list
headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
# exclude the first column as we will not need the ranking order from Basketball Reference for the analysis
headers = headers[1:]
headers
# Out:
# ['Age',
#  'Tm',
#  'Lg',
#  'Pos',
#  'G',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  '2P',
#  '2PA',
#  '2P%',
#  'eFG%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS']
